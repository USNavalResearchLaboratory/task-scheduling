# %%
import numpy as np
import matplotlib.pyplot as plt

print("hi")
x = np.linspace(0, 1, 100)
y = np.sin(2 * np.pi * x)
plt.plot(x, y)
# Out:
# hi

# %%
z = x * y
plt.plot(x, z, 'r')

# %%
import torch

t = torch.from_numpy(z)
